# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import regex as rg
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.base import BaseEstimator,TransformerMixin
import joblib as jb

# %%
path = os.path.join("House")
def load_csv(path,filename):
    return pd.read_csv(os.path.join(filename))

# %%
train_data = load_csv(path,"train.csv")
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
def relative_attribute_sale(attribute,train_data):
    return pd.DataFrame(train_data.groupby(by= attribute)['SalePrice'].mean().reset_index().sort_values(by = "SalePrice",ascending = True))

# %%
train_data = train_data.replace(755000,533000)
train_data = train_data.replace(745000,553000)

# %% [markdown]
# ## Missing percent

# %%
na_list = set([i if len(set(train_data[i].isna())) == 2 else 0 for i in list(train_data)])
na_list.remove(0)
print(na_list)
# Out:
# {'BsmtFinType2', 'Fence', 'BsmtQual', 'GarageYrBlt', 'BsmtExposure', 'GarageQual', 'GarageFinish', 'MasVnrType', 'Electrical', 'GarageCond', 'MasVnrArea', 'FireplaceQu', 'PoolQC', 'LotFrontage', 'BsmtFinType1', 'Alley', 'GarageType', 'MiscFeature', 'BsmtCond'}

# %% [markdown]
# Garage,Fence,Bsmt,alley,MasVnr,Misc,

# %%
percent_nan = {}
for attribute in na_list:
    percent_nan[attribute] = (train_data[attribute].isna().sum() / train_data[attribute].shape[0])*100
print(percent_nan)
# Out:
# {'BsmtFinType2': 2.6027397260273974, 'Fence': 80.75342465753424, 'BsmtQual': 2.5342465753424657, 'GarageYrBlt': 5.5479452054794525, 'BsmtExposure': 2.6027397260273974, 'GarageQual': 5.5479452054794525, 'GarageFinish': 5.5479452054794525, 'MasVnrType': 0.547945205479452, 'Electrical': 0.0684931506849315, 'GarageCond': 5.5479452054794525, 'MasVnrArea': 0.547945205479452, 'FireplaceQu': 47.26027397260274, 'PoolQC': 99.52054794520548, 'LotFrontage': 17.73972602739726, 'BsmtFinType1': 2.5342465753424657, 'Alley': 93.76712328767123, 'GarageType': 5.5479452054794525, 'MiscFeature': 96.30136986301369, 'BsmtCond': 2.5342465753424657}

# %%
garage_percent = percent_nan['GarageCond']
temp_percent_nan = percent_nan.copy()
for key,value in temp_percent_nan.items():
    if rg.findall("Garage",key):
        percent_nan.pop(key)
percent_nan['Garage'] = garage_percent

# %%
percent_nan
# Out:
# {'BsmtFinType2': 2.6027397260273974,
#  'Fence': 80.75342465753424,
#  'BsmtQual': 2.5342465753424657,
#  'BsmtExposure': 2.6027397260273974,
#  'MasVnrType': 0.547945205479452,
#  'Electrical': 0.0684931506849315,
#  'MasVnrArea': 0.547945205479452,
#  'FireplaceQu': 47.26027397260274,
#  'PoolQC': 99.52054794520548,
#  'LotFrontage': 17.73972602739726,
#  'BsmtFinType1': 2.5342465753424657,
#  'Alley': 93.76712328767123,
#  'MiscFeature': 96.30136986301369,
#  'BsmtCond': 2.5342465753424657,
#  'Garage': 5.5479452054794525}

# %%
percent_nan = pd.DataFrame.from_dict(percent_nan,orient='index').reset_index().rename({'index':'Name',0:'Missing Percent'},axis=1)

# %%
percent_nan.sort_values(by = 'Missing Percent',inplace=True)

# %%
percent_nan
# Out:
#             Name  Missing Percent
# 5     Electrical         0.068493
# 4     MasVnrType         0.547945
# 6     MasVnrArea         0.547945
# 2       BsmtQual         2.534247
# 10  BsmtFinType1         2.534247
# 13      BsmtCond         2.534247
# 0   BsmtFinType2         2.602740
# 3   BsmtExposure         2.602740
# 14        Garage         5.547945
# 9    LotFrontage        17.739726
# 7    FireplaceQu        47.260274
# 1          Fence        80.753425
# 11         Alley        93.767123
# 12   MiscFeature        96.301370
# 8         PoolQC        99.520548

# %%
plt.figure(figsize = (20,5))
plt.title("Missing percent")
sns.barplot(data = percent_nan,x='Name',y= 'Missing Percent',order = percent_nan['Name'])
# Out:
# <AxesSubplot:title={'center':'Missing percent'}, xlabel='Name', ylabel='Missing Percent'>

# %%
def ScaleNotChangePrice(attribute,point_attribute,train_data= train_data):
    mean_price = train_data[train_data[attribute] == point_attribute]["SalePrice"].mean()
    interval = [mean_price-30000,mean_price+30000]
    return train_data[(train_data['SalePrice'] > interval[0]) & (train_data['SalePrice'] < interval[1])][attribute].mean()

# %% [markdown]
# ### MSSUBCLASS

# %%
train_data['MSSubClass'].value_counts().index
# Out:
# Int64Index([20, 60, 50, 120, 30, 160, 70, 80, 90, 190, 85, 75, 45, 180, 40], dtype='int64')

# %%
train_data['MSSubClass'].value_counts(ascending=True).index
# Out:
# Int64Index([40, 180, 45, 75, 85, 190, 90, 80, 70, 160, 30, 120, 50, 60, 20], dtype='int64')

# %%
train_data['MSSubClass'].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
train_data.groupby(by = 'MSSubClass')['SalePrice'].mean().sort_values(ascending = True).index
# Out:
# Int64Index([30, 180, 45, 190, 90, 160, 50, 85, 40, 70, 80, 20, 75, 120, 60], dtype='int64', name='MSSubClass')

# %%
sns.barplot(data = train_data,x='MSSubClass',y='SalePrice',order = train_data.groupby(by = 'MSSubClass')['SalePrice'].mean().sort_values(ascending = True).index)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %% [markdown]
# ## MSZoning

# %%
train_data.groupby('MSZoning').mean().sort_values(by='SalePrice')['SalePrice']
# Out:
# MSZoning
# C (all)     74528.000000
# RM         126316.830275
# RH         131558.375000
# RL         190645.307559
# FV         214014.061538
# Name: SalePrice, dtype: float64

# %%
sns.barplot(data = train_data,x = 'MSZoning',y = 'SalePrice',order = train_data.groupby('MSZoning').mean().sort_values(by='SalePrice')['SalePrice'].index)
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %% [markdown]
# ## LotFrontage: has NAN (use SimpleImputer)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x = 'LotFrontage',y= 'SalePrice')
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %%
train_data['LotFrontage'] = train_data['LotFrontage'].apply(lambda x: ScaleNotChangePrice("LotFrontage",x) if x > 250 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x = 'LotFrontage',y= 'SalePrice')
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='SalePrice'>

# %% [markdown]
# ## Lot Area

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x = 'LotArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
train_data['LotArea'] = train_data['LotArea'].apply(lambda x: ScaleNotChangePrice("LotArea",x) if x > 100000 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x = 'LotArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %% [markdown]
# ## Street

# %%
train_data['Street'].value_counts()
# Out:
# Pave    1454
# Grvl       6
# Name: Street, dtype: int64

# %%
sns.barplot(data = train_data, x = 'Street',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Street', ylabel='SalePrice'>

# %% [markdown]
# ## Alley: has NAN

# %%
train_data['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
len(train_data['Alley'].isna())
# Out:
# 1460

# %%
train_data['Alley'] = train_data['Alley'].fillna("0")

# %%
sns.boxplot(data = train_data,x = 'Alley',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Alley', ylabel='SalePrice'>

# %% [markdown]
# ## LotShape

# %%
train_data['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
sns.boxplot(data = train_data,x = 'LotShape',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LotShape', ylabel='SalePrice'>

# %% [markdown]
# ## LandContour

# %%
sns.barplot(data = train_data,x = 'LandContour',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='SalePrice'>

# %% [markdown]
# ## Utilities

# %%
train_data['Utilities'].value_counts() #????
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
train_data['Utilities'] = train_data['Utilities'].apply(lambda x:"AllPub")

# %%
sns.barplot(data = train_data,x = 'Utilities',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Utilities', ylabel='SalePrice'>

# %% [markdown]
# ## LotConfig

# %%
sns.barplot(data = train_data,x='LotConfig',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# ## LandSlope

# %%
sns.barplot(data = train_data,x='LandSlope',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LandSlope', ylabel='SalePrice'>

# %% [markdown]
# ## Neighborhood

# %%
train_data['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
plt.figure(figsize = (20,20))
sns.barplot(data = train_data,x='Neighborhood',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# group ?

# %% [markdown]
# ## Condition1 + Condition2

# %%
sns.barplot(data = train_data,x = 'Condition1',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Condition1', ylabel='SalePrice'>

# %%
sns.barplot(data = train_data,x = 'Condition2',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Condition2', ylabel='SalePrice'>

# %% [markdown]
# ## BldgType

# %%
sns.barplot(data = train_data,x='BldgType',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='SalePrice'>

# %% [markdown]
# ## HouseStyle

# %%
sns.barplot(data = train_data,x='HouseStyle',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='SalePrice'>

# %% [markdown]
# ## OverallQual + OverallCond

# %%
sns.barplot(data = train_data,x='OverallQual',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.barplot(data = train_data,x='OverallCond',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallCond', ylabel='SalePrice'>

# %% [markdown]
# why 5 and 2 ? outlier

# %% [markdown]
# ## Year Built

# %%
plt.figure(figsize = (15,15))
sns.scatterplot(data = train_data,x='YearBuilt',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %% [markdown]
# higher year => higher price

# %% [markdown]
# ## YearRemodAdd

# %%
plt.figure(figsize = (15,15))
sns.scatterplot(data = train_data,x='YearRemodAdd',y='SalePrice',hue = 'YearRemodAdd')
# Out:
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='SalePrice'>

# %% [markdown]
# same as YearBuilt

# %% [markdown]
# ## RoofStyle

# %%
train_data['RoofStyle'].value_counts()
# Out:
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64

# %%
sns.barplot(data = train_data,x='RoofStyle',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='RoofStyle', ylabel='SalePrice'>

# %% [markdown]
# ## RoofMatl

# %%
plt.figure(figsize = (10,5))
sns.barplot(data = train_data,x='RoofMatl',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='RoofMatl', ylabel='SalePrice'>

# %% [markdown]
# ## Exterior1st + 2nd

# %%
train_data['Exterior1st'].value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# AsphShn      1
# ImStucc      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
plt.figure(figsize = (15,5))
sns.barplot(data = train_data,x='Exterior1st',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Exterior1st', ylabel='SalePrice'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(data = train_data,x='Exterior2nd',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Exterior2nd', ylabel='SalePrice'>

# %% [markdown]
# ## MasVnrType: has NAN

# %%
train_data['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
train_data['MasVnrType'] = train_data['MasVnrType'].fillna("0")

# %%
sns.barplot(data = train_data,x='MasVnrType',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MasVnrType', ylabel='SalePrice'>

# %% [markdown]
# ## MasVnrArea: has NAN (simpleImputer)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='MasVnrArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='SalePrice'>

# %%
train_data['MasVnrArea'] = train_data['MasVnrArea'].apply(lambda x: ScaleNotChangePrice("MasVnrArea",x) if x > 1350 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='MasVnrArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='SalePrice'>

# %% [markdown]
# ## ExterQual + ExterCond

# %%
sns.barplot(data = train_data,x='ExterQual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='ExterQual', ylabel='SalePrice'>

# %%
sns.barplot(data = train_data,x='ExterCond',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='ExterCond', ylabel='SalePrice'>

# %% [markdown]
# ## Foundation

# %%
sns.barplot(data = train_data,x='Foundation',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Foundation', ylabel='SalePrice'>

# %% [markdown]
# ## Basement: has NAN

# %% [markdown]
# ### BsmtQual

# %%
train_data['BsmtQual'].value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
train_data['BsmtQual'] = train_data['BsmtQual'].fillna("0")

# %%
sns.barplot(data = train_data,x='BsmtQual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtQual', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtCond

# %%
train_data['BsmtCond'].value_counts()
# Out:
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64

# %%
train_data['BsmtCond'] = train_data['BsmtCond'].fillna("0")

# %%
sns.barplot(data = train_data,x='BsmtCond',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtCond', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtExposure

# %%
train_data['BsmtExposure'].value_counts()
# Out:
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64

# %%
train_data['BsmtExposure'] = train_data['BsmtExposure'].fillna("0")

# %%
sns.barplot(data = train_data,x='BsmtExposure',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtExposure', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtFinType1

# %%
train_data['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
train_data['BsmtFinType1'] = train_data['BsmtFinType1'].fillna("0")

# %%
sns.barplot(data = train_data,x='BsmtFinType1',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinType1', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtFinSF1

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data=train_data,x='BsmtFinSF1',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinSF1', ylabel='SalePrice'>

# %%
train_data["BsmtFinSF1"] = train_data["BsmtFinSF1"].apply(lambda x: ScaleNotChangePrice("BsmtFinSF1",x) if x > 4000 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data=train_data,x='BsmtFinSF1',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinSF1', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtFinType2

# %%
train_data['BsmtFinType2'].value_counts()
# Out:
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
train_data['BsmtFinType2'] = train_data['BsmtFinType2'].fillna("0")

# %%
sns.barplot(data = train_data,x='BsmtFinType2',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinType2', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtFinSF2

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='BsmtFinSF2',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinSF2', ylabel='SalePrice'>

# %%
train_data['BsmtFinSF2'] = train_data['BsmtFinSF2'].apply(lambda x: ScaleNotChangePrice("BsmtFinSF2",x) if x> 1300 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='BsmtFinSF2',y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFinSF2', ylabel='SalePrice'>

# %% [markdown]
# ### BsmtUnfSF

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='BsmtUnfSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtUnfSF', ylabel='SalePrice'>

# %% [markdown]
# how ???

# %% [markdown]
# ### TotalBsmtSF

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='TotalBsmtSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
train_data['TotalBsmtSF'] = train_data['TotalBsmtSF'].apply(lambda x: ScaleNotChangePrice('TotalBsmtSF',x) if x> 3000 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='TotalBsmtSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %% [markdown]
# ## Heating

# %% [markdown]
# ### Heating

# %%
sns.barplot(data = train_data,x='Heating',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='SalePrice'>

# %% [markdown]
# ### HeatingQC

# %%
sns.barplot(data = train_data,x='HeatingQC',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='HeatingQC', ylabel='SalePrice'>

# %% [markdown]
# ## CentralAir

# %%
sns.barplot(data = train_data,x='CentralAir',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='CentralAir', ylabel='SalePrice'>

# %% [markdown]
# ## Electrical

# %%
train_data['Electrical'].fillna(train_data['Electrical'].value_counts().index[0],inplace=True)

# %%
sns.barplot(data = train_data,x='Electrical',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='SalePrice'>

# %% [markdown]
# ## 1stFlrSF

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='1stFlrSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
train_data['1stFlrSF'] = train_data['1stFlrSF'].apply(lambda x:ScaleNotChangePrice('1stFlrSF',x) if x> 2800 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='1stFlrSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %% [markdown]
# ## 2ndFlrSF

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='2ndFlrSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %% [markdown]
# ## LowQualFinSF

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='LowQualFinSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='LowQualFinSF', ylabel='SalePrice'>

# %% [markdown]
# ## GrLivArea

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='GrLivArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
train_data['GrLivArea'] = train_data['GrLivArea'].apply(lambda x: ScaleNotChangePrice('GrLivArea',x) if x > 4500 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='GrLivArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# ## Bathroom

# %% [markdown]
# ### BsmtFullBath

# %%
train_data['BsmtFullBath'].value_counts()
# Out:
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64

# %%
sns.barplot(data = train_data,x='BsmtFullBath',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtFullBath', ylabel='SalePrice'>

# %% [markdown]
# 2,3 ??

# %% [markdown]
# ### BsmtHalfBath

# %%
train_data['BsmtHalfBath'].value_counts()
# Out:
# 0    1378
# 1      80
# 2       2
# Name: BsmtHalfBath, dtype: int64

# %%
sns.barplot(data = train_data,x='BsmtHalfBath',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BsmtHalfBath', ylabel='SalePrice'>

# %% [markdown]
# ### FullBath

# %%
train_data['FullBath'].value_counts()
# Out:
# 2    768
# 1    650
# 3     33
# 0      9
# Name: FullBath, dtype: int64

# %%
sns.barplot(data = train_data,x='FullBath',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='FullBath', ylabel='SalePrice'>

# %% [markdown]
# ### HalfBath

# %%
sns.barplot(data = train_data,x='HalfBath',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='HalfBath', ylabel='SalePrice'>

# %% [markdown]
# ## BedroomAbvGr

# %%
sns.barplot(data = train_data,x='BedroomAbvGr',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='BedroomAbvGr', ylabel='SalePrice'>

# %% [markdown]
# ## Kitchen

# %% [markdown]
# ### KitchenAbvGr

# %%
sns.barplot(data = train_data,x='KitchenAbvGr',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='KitchenAbvGr', ylabel='SalePrice'>

# %% [markdown]
# ### KitchenQual

# %%
sns.barplot(data = train_data,x='KitchenQual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='KitchenQual', ylabel='SalePrice'>

# %% [markdown]
# ## TotRmsAbvGrd (does not include bathrooms)

# %%
sns.barplot(data = train_data,x='TotRmsAbvGrd',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='TotRmsAbvGrd', ylabel='SalePrice'>

# %% [markdown]
# ## Home functionality

# %%
sns.barplot(data = train_data,x='Functional',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Functional', ylabel='SalePrice'>

# %% [markdown]
# ## FirePlace

# %% [markdown]
# ### Fireplaces : Number of fireplaces

# %%
sns.barplot(data = train_data,x='Fireplaces',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Fireplaces', ylabel='SalePrice'>

# %% [markdown]
# ### FireplaceQual

# %%
train_data['FireplaceQu'].isna().sum()
train_data['FireplaceQu'].fillna("0",inplace=True)

# %%
sns.barplot(data = train_data,x='FireplaceQu',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='FireplaceQu', ylabel='SalePrice'>

# %% [markdown]
# ## Garage: has NAN

# %% [markdown]
# ### GarageType

# %%
train_data['GarageType'] = train_data['GarageType'].fillna("0")

# %%
sns.barplot(data = train_data,x='GarageType',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageType', ylabel='SalePrice'>

# %% [markdown]
# ### GarageYrBlt

# %%
train_data['GarageYrBlt'].fillna(0,inplace = True)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='GarageYrBlt',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='SalePrice'>

# %% [markdown]
# ### GarageFinish

# %%
train_data['GarageFinish'].fillna("0",inplace=True)

# %%
sns.barplot(data = train_data,x='GarageFinish',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageFinish', ylabel='SalePrice'>

# %% [markdown]
# ### GarageCars

# %%
train_data['GarageCars'].value_counts()
# Out:
# 2    824
# 1    369
# 3    181
# 0     81
# 4      5
# Name: GarageCars, dtype: int64

# %%
sns.barplot(data= train_data,x='GarageCars',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageCars', ylabel='SalePrice'>

# %% [markdown]
# ### GarageArea

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='GarageArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
train_data['GarageArea'] = train_data['GarageArea'].apply(lambda x:ScaleNotChangePrice('GarageArea',x) if x > 1200 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='GarageArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %% [markdown]
# ### GarageQual

# %%
train_data['GarageQual'].fillna("0",inplace=True)

# %%
sns.barplot(data = train_data,x='GarageQual',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageQual', ylabel='SalePrice'>

# %% [markdown]
# ### GarageCond

# %%
train_data['GarageCond'].fillna("0",inplace=True)

# %%
sns.barplot(data= train_data,x='GarageCond',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GarageCond', ylabel='SalePrice'>

# %% [markdown]
# ## PavedDrive: Paved driveway

# %%
sns.barplot(data = train_data,x='PavedDrive',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='PavedDrive', ylabel='SalePrice'>

# %% [markdown]
# ## WoodDeckSF: a wooden floor built outside, where people can sit and relax

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = train_data,x='WoodDeckSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='WoodDeckSF', ylabel='SalePrice'>

# %%
train_data['WoodDeckSF'] = train_data['WoodDeckSF'].apply(lambda x: ScaleNotChangePrice('WoodDeckSF',x) if x > 800 else x)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = train_data,x='WoodDeckSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='WoodDeckSF', ylabel='SalePrice'>

# %% [markdown]
# ## OpenPorchSF: Open porch area in square feet

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='OpenPorchSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='OpenPorchSF', ylabel='SalePrice'>

# %%
train_data['OpenPorchSF'] = train_data['OpenPorchSF'].apply(lambda x: ScaleNotChangePrice('OpenPorchSF',x) if x > 300 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='OpenPorchSF',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='OpenPorchSF', ylabel='SalePrice'>

# %% [markdown]
# ## EnclosedPorch: Enclosed porch area in square feet

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='EnclosedPorch',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='EnclosedPorch', ylabel='SalePrice'>

# %%
train_data['EnclosedPorch'] = train_data['EnclosedPorch'].apply(lambda x: ScaleNotChangePrice('EnclosedPorch',x) if x > 350 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='EnclosedPorch',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='EnclosedPorch', ylabel='SalePrice'>

# %% [markdown]
# ## 3SsnPorch: Three season porch area in square feet

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='3SsnPorch',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='3SsnPorch', ylabel='SalePrice'>

# %%
train_data['3SsnPorch'] = train_data['3SsnPorch'].apply(lambda x: ScaleNotChangePrice('3SsnPorch',x) if x > 280 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='3SsnPorch',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='3SsnPorch', ylabel='SalePrice'>

# %% [markdown]
# ## ScreenPorch: Screen porch area in square feet

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=train_data,x='ScreenPorch',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='ScreenPorch', ylabel='SalePrice'>

# %% [markdown]
# ## Pool

# %% [markdown]
# ### PoolArea

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = train_data,x='PoolArea',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='PoolArea', ylabel='SalePrice'>

# %% [markdown]
# ### PoolQC

# %%
train_data['PoolQC'] = train_data['PoolQC'].fillna("0")

# %%
train_data[train_data['PoolQC'] == 'Ex']
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0  25419.0   Pave     0      Reg
# 1182  1183          60       RL        160.0  15623.0   Pave     0      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 197       3   2006        WD        Abnorml     235000
# 1182      7   2007        WD        Abnorml     553000
#
# [2 rows x 81 columns]

# %%
sns.barplot(data = train_data,x='PoolQC',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='PoolQC', ylabel='SalePrice'>

# %% [markdown]
# ## Fence: Fence quality

# %%
train_data['Fence'] = train_data['Fence'].fillna("0")

# %%
sns.barplot(data = train_data,x='Fence',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='Fence', ylabel='SalePrice'>

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# ### MiscFeature: Miscellaneous feature not covered in other categories

# %%
train_data['MiscFeature'] = train_data['MiscFeature'].fillna("0")

# %%
sns.barplot(data = train_data,x='MiscFeature',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MiscFeature', ylabel='SalePrice'>

# %% [markdown]
# ### MiscVal

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='MiscVal',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MiscVal', ylabel='SalePrice'>

# %%
train_data['MiscVal'] = train_data['MiscVal'].apply(lambda x: ScaleNotChangePrice('MiscVal',x) if x > 1000 else x)

# %%
plt.figure(figsize = (10,10))
sns.scatterplot(data = train_data,x='MiscVal',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MiscVal', ylabel='SalePrice'>

# %% [markdown]
# ## Time Sold

# %% [markdown]
# ### MoSold: Month

# %%
plt.figure(figsize=(10,10))
sns.boxenplot(data = train_data,x='MoSold',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='MoSold', ylabel='SalePrice'>

# %% [markdown]
# ### YrSold: Year Sold

# %%
plt.figure(figsize=(10,10))
sns.boxenplot(data = train_data,x='YrSold',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='YrSold', ylabel='SalePrice'>

# %% [markdown]
# ## Sale

# %% [markdown]
# ## SaleType

# %%
sns.barplot(data = train_data,x='SaleType',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='SaleType', ylabel='SalePrice'>

# %% [markdown]
# ## SaleCondition

# %%
sns.barplot(data = train_data,x='SaleCondition',y='SalePrice')
# Out:
# <AxesSubplot:xlabel='SaleCondition', ylabel='SalePrice'>

# %% [markdown]
# # Correlation

# %%
train_data.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.028478  0.002565    -0.028365
# MSSubClass     0.011156    1.000000    -0.416063 -0.270968     0.032628
# LotFrontage   -0.028478   -0.416063     1.000000  0.466900     0.245231
# LotArea        0.002565   -0.270968     0.466900  1.000000     0.179544
# OverallQual   -0.028365    0.032628     0.245231  0.179544     1.000000
# OverallCond    0.012609   -0.059316    -0.072166 -0.020939    -0.091932
# YearBuilt     -0.012713    0.027850     0.127461  0.041668     0.572323
# YearRemodAdd  -0.021998    0.040581     0.078209  0.036868     0.550684
# MasVnrArea    -0.047294    0.023175     0.187804  0.158720     0.417971
# BsmtFinSF1    -0.016318   -0.073775     0.162049  0.209288     0.228002
# BsmtFinSF2    -0.000079   -0.067945     0.056074  0.082084    -0.064854
# BsmtUnfSF     -0.007940   -0.140759     0.156553  0.037635     0.308159
# TotalBsmtSF   -0.021497   -0.253178     0.348792  0.278000     0.536493
# 1stFlrSF       0.003414   -0.262479     0.403120  0.357138     0.467070
# 2ndFlrSF       0.005590    0.307886     0.082457  0.111931     0.295493
# LowQualFinSF  -0.044230    0.046474     0.044498  0.017064    -0.030429
# GrLivArea      0.002901    0.076771     0.361987  0.341294     0.585979
# BsmtFullBath   0.002289    0.003491     0.072355  0.152556     0.111098
# BsmtHalfBath  -0.020155   -0.002333    -0.003709  0.028799    -0.040150
# FullBath       0.005587    0.131608     0.203498  0.165989     0.550600
# HalfBath       0.006784    0.177354     0.053910  0.079801     0.273458
# BedroomAbvGr   0.037719   -0.023438     0.274055  0.193069     0.101676
# KitchenAbvGr   0.002951    0.281721    -0.002605 -0.016251    -0.183882
# TotRmsAbvGrd   0.027239    0.040380     0.341503  0.314741     0.427452
# Fireplaces    -0.019772   -0.045569     0.250796  0.325004     0.396765
# GarageYrBlt    0.013491   -0.080997     0.110444  0.113128     0.288998
# GarageCars     0.016570   -0.040110     0.307522  0.251208     0.600671
# GarageArea     0.008647   -0.105307     0.329977  0.260620     0.572436
# WoodDeckSF    -0.024327   -0.009645     0.096245  0.199347     0.234498
# OpenPorchSF   -0.009403   -0.002627     0.129757  0.155377     0.336166
# EnclosedPorch  0.010737   -0.016553    -0.015389 -0.025092    -0.129975
# 3SsnPorch     -0.037759   -0.018453     0.043605  0.029752     0.023352
# ScreenPorch    0.001330   -0.026030     0.050231  0.095613     0.064886
# PoolArea       0.057044    0.008283     0.114754  0.142125     0.065166
# MiscVal       -0.069857   -0.030145     0.016435  0.007758    -0.084304
# MoSold         0.021172   -0.013585     0.014576 -0.002990     0.070815
# YrSold         0.000712   -0.021407     0.005462 -0.030617    -0.027347
# SalePrice     -0.024028   -0.086373     0.378648  0.359622     0.797785
#
#                OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id                0.012609  -0.012713     -0.021998   -0.047294   -0.016318
# MSSubClass       -0.059316   0.027850      0.040581    0.023175   -0.073775
# LotFrontage      -0.072166   0.127461      0.078209    0.187804    0.162049
# LotArea          -0.020939   0.041668      0.036868    0.158720    0.209288
# OverallQual      -0.091932   0.572323      0.550684    0.417971    0.228002
# OverallCond       1.000000  -0.375983      0.073741   -0.128612   -0.044203
# YearBuilt        -0.375983   1.000000      0.592855    0.320012    0.251461
# YearRemodAdd      0.073741   0.592855      1.000000    0.181075    0.125405
# MasVnrArea       -0.128612   0.320012      0.181075    1.000000    0.248441
# BsmtFinSF1       -0.044203   0.251461      0.125405    0.248441    1.000000
# BsmtFinSF2        0.044594  -0.053537     -0.070302   -0.077162   -0.045619
# BsmtUnfSF        -0.136841   0.149040      0.181133    0.121349   -0.517048
# TotalBsmtSF      -0.175435   0.402576      0.296133    0.355041    0.462349
# 1stFlrSF         -0.146787   0.283478      0.242643    0.339257    0.390447
# 2ndFlrSF          0.028942   0.010308      0.140024    0.167879   -0.154956
# LowQualFinSF      0.025494  -0.183784     -0.062419   -0.070463   -0.066601
# GrLivArea        -0.077372   0.194114      0.286427    0.369201    0.141659
# BsmtFullBath     -0.054942   0.187599      0.119470    0.091422    0.655371
# BsmtHalfBath      0.117821  -0.038162     -0.012337    0.029221    0.072617
# FullBath         -0.194149   0.468271      0.439046    0.278030    0.054870
# HalfBath         -0.060769   0.242656      0.183331    0.199372   -0.005594
# BedroomAbvGr      0.012980  -0.070651     -0.040581    0.103517   -0.113829
# KitchenAbvGr     -0.087001  -0.174800     -0.149598   -0.037359   -0.083146
# TotRmsAbvGrd     -0.057583   0.095589      0.191740    0.285443    0.018785
# Fireplaces       -0.023820   0.147716      0.112581    0.252916    0.242087
# GarageYrBlt      -0.006515   0.272029      0.146357    0.136117    0.118864
# GarageCars       -0.185758   0.537850      0.420622    0.372165    0.232210
# GarageArea       -0.143303   0.488281      0.380444    0.370329    0.279382
# WoodDeckSF       -0.001542   0.226572      0.207953    0.170829    0.197680
# OpenPorchSF      -0.049611   0.248963      0.269701    0.150603    0.077292
# EnclosedPorch     0.076477  -0.378644     -0.207118   -0.109528   -0.112617
# 3SsnPorch         0.052555   0.020165      0.051942    0.020650    0.034163
# ScreenPorch       0.054811  -0.050364     -0.038740    0.044934    0.067200
# PoolArea         -0.001985   0.004950      0.005829    0.012582    0.049833
# MiscVal           0.050964  -0.056274     -0.068692   -0.038659   -0.009735
# MoSold           -0.003511   0.012398      0.021490   -0.005785   -0.000342
# YrSold            0.043950  -0.013618      0.035743   -0.003272    0.013908
# SalePrice        -0.079410   0.531340      0.516187    0.481397    0.404848
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id             ...   -0.024327    -0.009403       0.010737  -0.037759
# MSSubClass     ...   -0.009645    -0.002627      -0.016553  -0.018453
# LotFrontage    ...    0.096245     0.129757      -0.015389   0.043605
# LotArea        ...    0.199347     0.155377      -0.025092   0.029752
# OverallQual    ...    0.234498     0.336166      -0.129975   0.023352
# OverallCond    ...   -0.001542    -0.049611       0.076477   0.052555
# YearBuilt      ...    0.226572     0.248963      -0.378644   0.020165
# YearRemodAdd   ...    0.207953     0.269701      -0.207118   0.051942
# MasVnrArea     ...    0.170829     0.150603      -0.109528   0.020650
# BsmtFinSF1     ...    0.197680     0.077292      -0.112617   0.034163
# BsmtFinSF2     ...    0.066304    -0.019938       0.037160  -0.031065
# BsmtUnfSF      ...   -0.001088     0.141395      -0.003221  -0.017345
# TotalBsmtSF    ...    0.236107     0.232203      -0.118654   0.006608
# 1stFlrSF       ...    0.234079     0.193576      -0.091896   0.029401
# 2ndFlrSF       ...    0.096146     0.205703       0.040230  -0.000761
# LowQualFinSF   ...   -0.025338     0.025989       0.014313   0.001148
# GrLivArea      ...    0.247694     0.316789      -0.015948   0.020484
# BsmtFullBath   ...    0.166765     0.065855      -0.055285   0.010628
# BsmtHalfBath   ...    0.041522    -0.018112      -0.032579   0.067632
# FullBath       ...    0.200143     0.285814      -0.120203   0.023290
# HalfBath       ...    0.105091     0.207686      -0.099737   0.018407
# BedroomAbvGr   ...    0.059904     0.096863       0.028482  -0.007306
# KitchenAbvGr   ...   -0.090517    -0.070183       0.041061  -0.023451
# TotRmsAbvGrd   ...    0.171387     0.251823      -0.005370  -0.005705
# Fireplaces     ...    0.200412     0.175382      -0.032200   0.023588
# GarageYrBlt    ...    0.117906     0.072103      -0.081377   0.027928
# GarageCars     ...    0.223345     0.242797      -0.172513   0.020350
# GarageArea     ...    0.218530     0.265679      -0.143225   0.029452
# WoodDeckSF     ...    1.000000     0.082543      -0.129715  -0.004851
# OpenPorchSF    ...    0.082543     1.000000      -0.100337   0.004137
# EnclosedPorch  ...   -0.129715    -0.100337       1.000000  -0.033286
# 3SsnPorch      ...   -0.004851     0.004137      -0.033286   1.000000
# ScreenPorch    ...   -0.074159     0.024480      -0.083332  -0.029967
# PoolArea       ...    0.074547     0.071931      -0.022719  -0.007618
# MiscVal        ...    0.043500    -0.012289       0.022453  -0.017711
# MoSold         ...    0.015140     0.069005      -0.020222   0.017784
# YrSold         ...    0.027399    -0.055391      -0.005638   0.012660
# SalePrice      ...    0.320685     0.359678      -0.144449   0.035815
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# Id                0.001330  0.057044 -0.069857  0.021172  0.000712  -0.024028
# MSSubClass       -0.026030  0.008283 -0.030145 -0.013585 -0.021407  -0.086373
# LotFrontage       0.050231  0.114754  0.016435  0.014576  0.005462   0.378648
# LotArea           0.095613  0.142125  0.007758 -0.002990 -0.030617   0.359622
# OverallQual       0.064886  0.065166 -0.084304  0.070815 -0.027347   0.797785
# OverallCond       0.054811 -0.001985  0.050964 -0.003511  0.043950  -0.079410
# YearBuilt        -0.050364  0.004950 -0.056274  0.012398 -0.013618   0.531340
# YearRemodAdd     -0.038740  0.005829 -0.068692  0.021490  0.035743   0.516187
# MasVnrArea        0.044934  0.012582 -0.038659 -0.005785 -0.003272   0.481397
# BsmtFinSF1        0.067200  0.049833 -0.009735 -0.000342  0.013908   0.404848
# BsmtFinSF2        0.093051  0.043306 -0.021093 -0.019525  0.036441  -0.020565
# BsmtUnfSF        -0.012579 -0.035092 -0.043409  0.034888 -0.041258   0.218270
# TotalBsmtSF       0.092061  0.034516 -0.064686  0.024830 -0.017853   0.649921
# 1stFlrSF          0.098085  0.059739 -0.049554  0.043936 -0.011841   0.631698
# 2ndFlrSF          0.040606  0.081487 -0.033793  0.035164 -0.028700   0.312739
# LowQualFinSF      0.026799  0.062157  0.020319 -0.022174 -0.028921  -0.025721
# GrLivArea         0.107779  0.108500 -0.063028  0.057574 -0.036033   0.730158
# BsmtFullBath      0.023148  0.067616  0.002691 -0.025361  0.067049   0.231761
# BsmtHalfBath      0.032121  0.020025  0.042149  0.032873 -0.046524  -0.024524
# FullBath         -0.008106  0.049604 -0.069802  0.055872 -0.019669   0.563277
# HalfBath          0.072426  0.022381 -0.022826 -0.009050 -0.010269   0.285770
# BedroomAbvGr      0.044300  0.070703 -0.030551  0.046544 -0.036014   0.166778
# KitchenAbvGr     -0.051613 -0.014525  0.011320  0.026589  0.031687  -0.138073
# TotRmsAbvGrd      0.059383  0.083757 -0.042927  0.036907 -0.034516   0.537441
# Fireplaces        0.184530  0.095074 -0.015643  0.046357 -0.024096   0.469169
# GarageYrBlt       0.061416  0.015858  0.004543  0.019151 -0.011134   0.266000
# GarageCars        0.050494  0.020934 -0.035221  0.040522 -0.039117   0.648230
# GarageArea        0.056436  0.025431 -0.041139  0.035269 -0.029683   0.647481
# WoodDeckSF       -0.074159  0.074547  0.043500  0.015140  0.027399   0.320685
# OpenPorchSF       0.024480  0.071931 -0.012289  0.069005 -0.055391   0.359678
# EnclosedPorch    -0.083332 -0.022719  0.022453 -0.020222 -0.005638  -0.144449
# 3SsnPorch        -0.029967 -0.007618 -0.017711  0.017784  0.012660   0.035815
# ScreenPorch       1.000000  0.051307 -0.024513  0.023217  0.010694   0.114841
# PoolArea          0.051307  1.000000 -0.007933 -0.033737 -0.059689   0.071274
# MiscVal          -0.024513 -0.007933  1.000000  0.011079  0.046940  -0.072157
# MoSold            0.023217 -0.033737  0.011079  1.000000 -0.145721   0.050863
# YrSold            0.010694 -0.059689  0.046940 -0.145721  1.000000  -0.027306
# SalePrice         0.114841  0.071274 -0.072157  0.050863 -0.027306   1.000000
#
# [38 rows x 38 columns]

# %%
_set = set()
for i in list(train_data.corr()):
    temp = dict(train_data.corr()[i])
    arr = []
    for key,value in temp.items():
        if ((value >= 0.3 and value < 1) or (value <=-0.3 and value > -1)):
            _set.add((i,key,value))

# %%
lst = []
for i in _set:
    lst.append(list(i))

# %%
index_first = 0
_len = len(lst)
while (index_first < _len):
    index_second = 0
    while (index_second < _len - 1 and index_first < _len):
        if lst[index_first][0] == lst[index_second][1] and lst[index_first][1] == lst[index_second][0]:
            lst.remove([lst[index_second][0],lst[index_second][1],lst[index_second][2]])
            index_second -= 1
            _len -= 1
        index_second += 1
    index_first += 1

# %%
lst.sort(key = lambda x:x[2],reverse=True)
lst
# Out:
# [['GarageArea', 'GarageCars', 0.8851914712915412],
#  ['TotRmsAbvGrd', 'GrLivArea', 0.8237795183280829],
#  ['1stFlrSF', 'TotalBsmtSF', 0.8063384986548977],
#  ['SalePrice', 'OverallQual', 0.7977845354150701],
#  ['SalePrice', 'GrLivArea', 0.7301576602293008],
#  ['2ndFlrSF', 'GrLivArea', 0.6924387552244028],
#  ['BedroomAbvGr', 'TotRmsAbvGrd', 0.676619935742649],
#  ['BsmtFinSF1', 'BsmtFullBath', 0.6553705354433607],
#  ['SalePrice', 'TotalBsmtSF', 0.6499210238994513],
#  ['SalePrice', 'GarageCars', 0.648229913641702],
#  ['GarageArea', 'SalePrice', 0.6474806808965745],
#  ['GrLivArea', 'FullBath', 0.6368256708715182],
#  ['1stFlrSF', 'SalePrice', 0.6316976180038248],
#  ['TotRmsAbvGrd', '2ndFlrSF', 0.6164226354915431],
#  ['2ndFlrSF', 'HalfBath', 0.6097073002717436],
#  ['GarageCars', 'OverallQual', 0.6006707165907149],
#  ['GarageCars', 'GarageYrBlt', 0.5980046450202292],
#  ['YearRemodAdd', 'YearBuilt', 0.5928549763436519],
#  ['GrLivArea', 'OverallQual', 0.5859788488490348],
#  ['GarageYrBlt', 'GarageArea', 0.5724825626571614],
#  ['OverallQual', 'GarageArea', 0.5724364992463162],
#  ['YearBuilt', 'OverallQual', 0.5723227689623621],
#  ['FullBath', 'SalePrice', 0.5632765804047078],
#  ['FullBath', 'TotRmsAbvGrd', 0.5547842535334836],
#  ['YearRemodAdd', 'OverallQual', 0.5506839241941717],
#  ['OverallQual', 'FullBath', 0.5505997093682543],
#  ['BedroomAbvGr', 'GrLivArea', 0.538070056488522],
#  ['GarageCars', 'YearBuilt', 0.5378500917111052],
#  ['TotRmsAbvGrd', 'SalePrice', 0.5374405322424192],
#  ['OverallQual', 'TotalBsmtSF', 0.5364929636007341],
#  ['SalePrice', 'YearBuilt', 0.5313398141122679],
#  ['1stFlrSF', 'GrLivArea', 0.5269432470394178],
#  ['SalePrice', 'YearRemodAdd', 0.516187381312643],
#  ['2ndFlrSF', 'BedroomAbvGr', 0.5029006133459056],
#  ['YearBuilt', 'GarageArea', 0.48828060141116436],
#  ['SalePrice', 'MasVnrArea', 0.4813973326190613],
#  ['1stFlrSF', 'GarageArea', 0.48020244109933524],
#  ['GarageArea', 'TotalBsmtSF', 0.47730651693791293],
#  ['GrLivArea', 'GarageCars', 0.4750530226936641],
#  ['FullBath', 'GarageCars', 0.469672043267628],
#  ['Fireplaces', 'SalePrice', 0.46916939356374265],
#  ['FullBath', 'YearBuilt', 0.4682707871726737],
#  ['OverallQual', '1stFlrSF', 0.4670703089098846],
#  ['LotFrontage', 'LotArea', 0.466899808144649],
#  ['GrLivArea', 'GarageArea', 0.46426811865452944],
#  ['TotalBsmtSF', 'BsmtFinSF1', 0.4623487875061182],
#  ['1stFlrSF', 'GarageCars', 0.4547765187496],
#  ['Fireplaces', 'GrLivArea', 0.4542781418405282],
#  ['TotalBsmtSF', 'GarageCars', 0.4538660629369694],
#  ['YearRemodAdd', 'FullBath', 0.4390464838723479],
#  ['TotalBsmtSF', 'BsmtUnfSF', 0.4340867156810169],
#  ['TotRmsAbvGrd', 'OverallQual', 0.42745234327798975],
#  ['FullBath', '2ndFlrSF', 0.4213779828759713],
#  ['GarageCars', 'YearRemodAdd', 0.42062215494321714],
#  ['HalfBath', 'GrLivArea', 0.4182897958092413],
#  ['MasVnrArea', 'OverallQual', 0.41797074396793776],
#  ['GarageArea', 'FullBath', 0.41743942567947423],
#  ['TotalBsmtSF', 'GrLivArea', 0.407268552181812],
#  ['SalePrice', 'BsmtFinSF1', 0.4048481624653732],
#  ['Fireplaces', '1stFlrSF', 0.40388843294012233],
#  ['1stFlrSF', 'LotFrontage', 0.4031199973718785],
#  ['YearBuilt', 'TotalBsmtSF', 0.4025762383679159],
#  ['Fireplaces', 'OverallQual', 0.39676503795208906],
#  ['BsmtFinSF1', '1stFlrSF', 0.3904473261869379],
#  ['1stFlrSF', 'TotRmsAbvGrd', 0.3890500653654155],
#  ['GarageArea', 'YearRemodAdd', 0.3804436742863882],
#  ['FullBath', '1stFlrSF', 0.3788425595167702],
#  ['SalePrice', 'LotFrontage', 0.3786475157168103],
#  ['MasVnrArea', 'GarageCars', 0.37216465459624043],
#  ['MasVnrArea', 'GarageArea', 0.3703294438456602],
#  ['MasVnrArea', 'GrLivArea', 0.3692009125862423],
#  ['BedroomAbvGr', 'FullBath', 0.36325198302327694],
#  ['GarageCars', 'TotRmsAbvGrd', 0.3622885708147746],
#  ['GrLivArea', 'LotFrontage', 0.36198737660684993],
#  ['OpenPorchSF', 'SalePrice', 0.3596784028296157],
#  ['LotArea', 'SalePrice', 0.35962154501928284],
#  ['1stFlrSF', 'LotArea', 0.3571384625836183],
#  ['MasVnrArea', 'TotalBsmtSF', 0.35504106576400996],
#  ['LotFrontage', 'TotalBsmtSF', 0.34879206861524636],
#  ['HalfBath', 'TotRmsAbvGrd', 0.3434148575409178],
#  ['TotRmsAbvGrd', 'LotFrontage', 0.3415034342547565],
#  ['LotArea', 'GrLivArea', 0.341293564754966],
#  ['1stFlrSF', 'MasVnrArea', 0.33925714633432774],
#  ['OpenPorchSF', 'OverallQual', 0.33616625293685887],
#  ['GarageArea', 'TotRmsAbvGrd', 0.33376290528995584],
#  ['BsmtUnfSF', '1stFlrSF', 0.33047722320373724],
#  ['GarageArea', 'LotFrontage', 0.3299767242800089],
#  ['Fireplaces', 'TotalBsmtSF', 0.32707751206383234],
#  ['Fireplaces', 'TotRmsAbvGrd', 0.3261144801772001],
#  ['LotArea', 'Fireplaces', 0.3250043486389183],
#  ['TotalBsmtSF', 'FullBath', 0.32498820336711043],
#  ['WoodDeckSF', 'SalePrice', 0.3206852782549119],
#  ['MasVnrArea', 'YearBuilt', 0.3200118164722148],
#  ['GrLivArea', 'OpenPorchSF', 0.31678870915846996],
#  ['LotArea', 'TotRmsAbvGrd', 0.3147410835060498],
#  ['2ndFlrSF', 'SalePrice', 0.3127392430377281],
#  ['OverallQual', 'BsmtUnfSF', 0.30815892690564284],
#  ['2ndFlrSF', 'MSSubClass', 0.30788572075985926],
#  ['GarageCars', 'LotFrontage', 0.3075221657325586],
#  ['Fireplaces', 'GarageCars', 0.3007887663013562],
#  ['OverallCond', 'YearBuilt', -0.37598319560698945],
#  ['YearBuilt', 'EnclosedPorch', -0.3786436869149773],
#  ['LotFrontage', 'MSSubClass', -0.41606322305774895],
#  ['BsmtUnfSF', 'BsmtFullBath', -0.42290047738321335],
#  ['BsmtFinSF1', 'BsmtUnfSF', -0.5170482287997894]]

# %% [markdown]
# ### Garage

# %%
garages =  []
for i in list(train_data):
    if rg.search("^Garage",i) or rg.search("Garage$",i):
        garages.append(i)
print(garages)
# Out:
# ['GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond']

# %%
sort_garage = []
for garage in garages:
    for i in lst:
        if garage in i and i not in sort_garage:
            sort_garage.append(i)
sort_garage.sort(key = lambda x:x[2],reverse = True)
sort_garage
# Out:
# [['GarageArea', 'GarageCars', 0.8851914712915412],
#  ['SalePrice', 'GarageCars', 0.648229913641702],
#  ['GarageArea', 'SalePrice', 0.6474806808965745],
#  ['GarageCars', 'OverallQual', 0.6006707165907149],
#  ['GarageCars', 'GarageYrBlt', 0.5980046450202292],
#  ['GarageYrBlt', 'GarageArea', 0.5724825626571614],
#  ['OverallQual', 'GarageArea', 0.5724364992463162],
#  ['GarageCars', 'YearBuilt', 0.5378500917111052],
#  ['YearBuilt', 'GarageArea', 0.48828060141116436],
#  ['1stFlrSF', 'GarageArea', 0.48020244109933524],
#  ['GarageArea', 'TotalBsmtSF', 0.47730651693791293],
#  ['GrLivArea', 'GarageCars', 0.4750530226936641],
#  ['FullBath', 'GarageCars', 0.469672043267628],
#  ['GrLivArea', 'GarageArea', 0.46426811865452944],
#  ['1stFlrSF', 'GarageCars', 0.4547765187496],
#  ['TotalBsmtSF', 'GarageCars', 0.4538660629369694],
#  ['GarageCars', 'YearRemodAdd', 0.42062215494321714],
#  ['GarageArea', 'FullBath', 0.41743942567947423],
#  ['GarageArea', 'YearRemodAdd', 0.3804436742863882],
#  ['MasVnrArea', 'GarageCars', 0.37216465459624043],
#  ['MasVnrArea', 'GarageArea', 0.3703294438456602],
#  ['GarageCars', 'TotRmsAbvGrd', 0.3622885708147746],
#  ['GarageArea', 'TotRmsAbvGrd', 0.33376290528995584],
#  ['GarageArea', 'LotFrontage', 0.3299767242800089],
#  ['GarageCars', 'LotFrontage', 0.3075221657325586],
#  ['Fireplaces', 'GarageCars', 0.3007887663013562]]

# %% [markdown]
# # Feature Importance

# %%
train_data.drop(columns= "Id")
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0   8450.0   Pave     0      Reg
# 1             20       RL         80.0   9600.0   Pave     0      Reg
# 2             60       RL         68.0  11250.0   Pave     0      IR1
# 3             70       RL         60.0   9550.0   Pave     0      IR1
# 4             60       RL         84.0  14260.0   Pave     0      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0   7917.0   Pave     0      Reg
# 1456          20       RL         85.0  13175.0   Pave     0      Reg
# 1457          70       RL         66.0   9042.0   Pave     0      Reg
# 1458          20       RL         68.0   9717.0   Pave     0      Reg
# 1459          20       RL         75.0   9937.0   Pave     0      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    Inside  ...        0      0      0           0
# 1            Lvl    AllPub       FR2  ...        0      0      0           0
# 2            Lvl    AllPub    Inside  ...        0      0      0           0
# 3            Lvl    AllPub    Corner  ...        0      0      0           0
# 4            Lvl    AllPub       FR2  ...        0      0      0           0
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1455         Lvl    AllPub    Inside  ...        0      0      0           0
# 1456         Lvl    AllPub    Inside  ...        0      0  MnPrv           0
# 1457         Lvl    AllPub    Inside  ...        0      0  GdPrv        Shed
# 1458         Lvl    AllPub    Inside  ...        0      0      0           0
# 1459         Lvl    AllPub    Inside  ...        0      0      0           0
#
#         MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0      0.000000      2    2008        WD         Normal     208500
# 1      0.000000      5    2007        WD         Normal     181500
# 2      0.000000      9    2008        WD         Normal     223500
# 3      0.000000      2    2006        WD        Abnorml     140000
# 4      0.000000     12    2008        WD         Normal     250000
# ...         ...    ...     ...       ...            ...        ...
# 1455   0.000000      8    2007        WD         Normal     175000
# 1456   0.000000      2    2010        WD         Normal     210000
# 1457  55.067568      5    2010        WD         Normal     266500
# 1458   0.000000      4    2010        WD         Normal     142125
# 1459   0.000000      6    2008        WD         Normal     147500
#
# [1460 rows x 80 columns]

# %%
y_train = train_data['SalePrice']
x_train = train_data.drop(columns=["Id","SalePrice"])

# %%
num = (list(x_train.describe()))
cate = []
for attr in list(x_train):
    if attr not in num:
        cate.append(attr)

# %%
num_pipeline = Pipeline([
    ("imputer",SimpleImputer(strategy='mean')),#use gridsearch
    ("scaler",StandardScaler())
])

# %%
cate_pipeline = Pipeline([
    ("imputer",SimpleImputer(strategy="most_frequent")),
    ("encoder",OrdinalEncoder())
])

# %%
prepare_pipeline = ColumnTransformer([
    ("num",num_pipeline,num),
    ("cate",cate_pipeline,cate)
])

# %%
x_train = prepare_pipeline.fit_transform(x_train)

# %%
# sgd_reg = SGDRegressor()

# %%
# param_grid = {
#     "penalty": ["l2","l1","elasticnet"],
#     "alpha": [0.0000001*i for i in range(1,71,10)],
#     "learning_rate": ["constant",'optimal','invscaling','adaptive'],
#     "early_stopping": [False,True]
# }

# %%
# grid_search = GridSearchCV(sgd_reg,param_grid=param_grid,cv = 10,scoring='neg_mean_squared_error',verbose = 2,refit=True)
# grid_search.fit(x_train,y_train)

# %%
# new_sgd = SGDRegressor(**grid_search.best_params_)

# %%
# new_sgd.fit(x_train,y_train)

# %%
param_grid_random = {
    # "n_estimators":[i for i in range(100,150)],
    "criterion":['mse','mae'],
    'max_features':['auto','sqrt','log2']
}

# %%
random_forest_reg = RandomForestRegressor()

# %%
grid_search = GridSearchCV(random_forest_reg,param_grid=param_grid_random,cv = 10,scoring='neg_mean_squared_error',verbose = 2,refit=True)
grid_search.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=auto; total time=   1.4s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=sqrt; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mse, max_features=log2; total time=   0.2s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.9s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.7s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.4s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.7s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.7s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.6s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.4s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.5s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.6s
# [CV] END ...................criterion=mae, max_features=auto; total time=  14.4s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   1.9s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   1.9s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   1.9s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   1.9s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=sqrt; total time=   2.0s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# [CV] END ...................criterion=mae, max_features=log2; total time=   1.6s
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2']},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
def feature_indicate(feature_important,k):
    return sorted(np.argpartition(feature_important,-k)[-k:])

# %%
feature_important = grid_search.best_estimator_.feature_importances_

# %%
atr_pipeline = num+cate

# %%
sorted(list(zip(feature_important,atr_pipeline)),key = lambda x: x[0],reverse=True)
# Out:
# [(0.5857208403875669, 'OverallQual'),
#  (0.12048457723357485, 'GrLivArea'),
#  (0.05460276166594349, 'TotalBsmtSF'),
#  (0.033399626287624926, 'BsmtFinSF1'),
#  (0.029523900227958776, '1stFlrSF'),
#  (0.021705161745533927, 'GarageArea'),
#  (0.013551979488349438, 'TotRmsAbvGrd'),
#  (0.012501850624685595, 'GarageCars'),
#  (0.01011759630031009, 'LotArea'),
#  (0.009758176356545375, 'YearBuilt'),
#  (0.006109637390180895, 'YearRemodAdd'),
#  (0.005803928380201496, 'GarageYrBlt'),
#  (0.00555948239996587, 'BsmtUnfSF'),
#  (0.005217142321345595, 'LotFrontage'),
#  (0.004954056592515809, 'OverallCond'),
#  (0.004891609904587475, 'MasVnrArea'),
#  (0.0047964417326437185, 'Neighborhood'),
#  (0.004385660614055216, 'OpenPorchSF'),
#  (0.0042351442103327076, 'FullBath'),
#  (0.0039830266617459755, '2ndFlrSF'),
#  (0.0036614209964490533, 'ExterQual'),
#  (0.0034118788660111375, 'GarageType'),
#  (0.0033832741659719687, 'WoodDeckSF'),
#  (0.0028947056907915906, 'KitchenQual'),
#  (0.0028239355295740535, 'MoSold'),
#  (0.0025417270097185802, 'FireplaceQu'),
#  (0.002397422294551056, 'BsmtQual'),
#  (0.0023864552238480026, 'BsmtExposure'),
#  (0.0022676977650211583, 'CentralAir'),
#  (0.0018296468068493275, 'MSZoning'),
#  (0.001790255970828484, 'GarageFinish'),
#  (0.0016977136721246626, 'LotShape'),
#  (0.0016375431214585674, 'Fireplaces'),
#  (0.0016139753299179791, 'Exterior1st'),
#  (0.001414042801515633, 'SaleCondition'),
#  (0.0013817075044598578, 'YrSold'),
#  (0.0013462117447058935, 'Exterior2nd'),
#  (0.0012884136243435731, 'MSSubClass'),
#  (0.0011690708345924732, 'HouseStyle'),
#  (0.001134193576932549, 'BedroomAbvGr'),
#  (0.0010378332238101477, 'BsmtFinType1'),
#  (0.00095786303931766, 'LandContour'),
#  (0.0009109780748123279, 'KitchenAbvGr'),
#  (0.0008836459769134234, 'ScreenPorch'),
#  (0.0008645071729161563, 'MasVnrType'),
#  (0.0007916502959084472, 'SaleType'),
#  (0.0007497287788007886, 'EnclosedPorch'),
#  (0.0007469180085944161, 'HalfBath'),
#  (0.0007397214536502774, 'RoofStyle'),
#  (0.0006971968217094336, 'BsmtFullBath'),
#  (0.0006868422698446478, 'HeatingQC'),
#  (0.0006765113129869893, 'LotConfig'),
#  (0.0005940456266252385, 'LandSlope'),
#  (0.0005825102253970267, 'BsmtFinSF2'),
#  (0.0004920819233201623, 'ExterCond'),
#  (0.00045848082481364413, 'Foundation'),
#  (0.00045223269056184236, 'GarageQual'),
#  (0.00041541004235459315, 'GarageCond'),
#  (0.00040438428596424283, 'BsmtCond'),
#  (0.0003850656203189306, 'Condition1'),
#  (0.00037475664208875225, 'Alley'),
#  (0.00036933635672557795, 'PavedDrive'),
#  (0.000349855470911139, 'Functional'),
#  (0.0003051839080129702, 'Fence'),
#  (0.00027506159787778076, '3SsnPorch'),
#  (0.00026790654303710556, 'BldgType'),
#  (0.00022193010012055186, 'BsmtFinType2'),
#  (0.00021306575481706703, 'BsmtHalfBath'),
#  (0.000167285644409104, 'RoofMatl'),
#  (0.00012872951530132703, 'LowQualFinSF'),
#  (0.00012117160864473357, 'Electrical'),
#  (0.00010061539309385346, 'MiscVal'),
#  (7.125654262030276e-05, 'Condition2'),
#  (5.2373526246697066e-05, 'PoolQC'),
#  (3.554538832995742e-05, 'Heating'),
#  (1.906193993618615e-05, 'MiscFeature'),
#  (1.777561071877364e-05, 'PoolArea'),
#  (7.5877331543275485e-06, 'Street'),
#  (0.0, 'Utilities')]

# %% [markdown]
# chon tuong quan, => fit > 700k

# %%
x_train = train_data.drop(columns=["Id","SalePrice"])

# %%
class SelectTopFeature(BaseEstimator,TransformerMixin):
    def __init__(self,feature_important,k):
        self.feature_important = feature_important
        self.k = k
    def fit(self,X,y=None):
        self.indicate_feature = feature_indicate(self.feature_important,self.k)
        return self
    def transform(self,X):
        return X[:,self.indicate_feature]

# %%
full_pipeline = Pipeline([
    ("prepare",prepare_pipeline),
    ("top_feature",SelectTopFeature(feature_important,67))
])

# %%
x_train_new = full_pipeline.fit_transform(x_train)

# %%
param_grid_random = {
    "n_estimators":[i for i in range(100,150)],
    "criterion":['poisson','mse','mae'],
    'max_features':['auto','sqrt','log2']
}

# %%
# grid_search = GridSearchCV(random_forest_reg,param_grid=param_grid_random,cv = 10,scoring='neg_mean_squared_error',verbose = 2,refit=True)
# grid_search.fit(x_train_new,y_train)

# %%
jb.dump(grid_search,"grid_search_randomforest.pkl")
# Out:
# ['grid_search_randomforest.pkl']

# %%
rd = jb.load("grid_search_randomforest.pkl")

# %%
rd.best_params_
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'n_estimators': 123}

# %%
random_forest_reg = RandomForestRegressor(**rd.best_params_)
random_forest_reg.fit(x_train_new,y_train)
# Out:
# RandomForestRegressor(n_estimators=123)

# %% [markdown]
# # Boosting

# %%
test = load_csv(path,"test.csv")

# %%
test.drop(columns="Id",inplace=True)

# %%
test_set = full_pipeline.transform(test)

# %%
test_predict = random_forest_reg.predict(test_set)

# %%
submit = pd.DataFrame({"Id":[i+1461 for i in range(len(test_set))],"SalePrice":test_predict})
submit.to_csv("submit.csv",index=False)
